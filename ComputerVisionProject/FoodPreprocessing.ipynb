# %%
# %matplotlib inline
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from ipywidgets import *

# %%
img_lane = cv2.imread('dataset/image_1.png')
plt.imshow(cv2.cvtColor(img_lane, cv2.COLOR_BGR2RGB))
#plt.imshow(img_lane)
print(img_lane.shape)
# Out:
# (364, 564, 3)
